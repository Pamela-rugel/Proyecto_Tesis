# %% [markdown]
# # 05. Catálogo de idiomas
#
# Proyecto de tesis (Maestria en Ciencia de Datos e IA, ESPOL): *Sistema de Generacion de Perfiles del Personal Docente y Administrativo en ESPOL para la asignacion inteligente de tareas*. Este notebook corresponde a la **Fase 1 y 2** de la metodologia: extraccion y depuracion de una de las fuentes institucionales que alimentan el catalogo de variables (historia laboral, capacitaciones, proyectos, experiencia y direcciones de tesis) usado para construir los perfiles multidimensionales del personal.
#
# **Fuente:** `data/raw/catalogoidiomas.csv`
# **Salida:** `data/processed/catalogo_idiomas.csv`
#
# Tabla catalogo (4 filas) con los idiomas disponibles. Sirve para validar idiomas_personas.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd()))
import pandas as pd
import _preprocesamiento_comun as pc

pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## 1. Carga de datos crudos

# %%
df = pc.leer_csv('catalogoidiomas.csv', low_memory=False)
df.head()
# Out:
# Leido catalogoidiomas.csv con encoding=utf-8-sig -> 4 filas, 2 columnas
#   DESCRIPCION CODIGOSTR
# 0     NINGUNA     N
# 1      BÁSICO     B
# 2  INTERMEDIO     I
# 3    AVANZADO     A

# %% [markdown]
# ## 2. Exploración inicial

# %%
pc.resumen(df, 'catalogo_idiomas')
# Out:
# --- Resumen catalogo_idiomas ---
# Dimensiones: 4 filas x 2 columnas
# Filas duplicadas: 0
# Sin columnas con valores nulos.

# %%
df.dtypes
# Out:
# DESCRIPCION    str
# CODIGOSTR      str
# dtype: object

# %% [markdown]
# ## 3. Limpieza

# %%
df = pc.limpiar_strings(df)
df = pc.quitar_columnas_vacias(df, umbral=0.99)
df = pc.quitar_columnas_constantes(df)

# %% [markdown]
# ## 7. Verificación final

# %%
pc.resumen(df, 'catalogo_idiomas (procesado)')
df.head()
# Out:
# --- Resumen catalogo_idiomas (procesado) ---
# Dimensiones: 4 filas x 2 columnas
# Filas duplicadas: 0
# Sin columnas con valores nulos.
#   DESCRIPCION CODIGOSTR
# 0     NINGUNA         N
# 1      BÁSICO         B
# 2  INTERMEDIO         I
# 3    AVANZADO         A

# %% [markdown]
# ## 8. Guardado en data/processed

# %%
pc.guardar_procesado(df, 'catalogo_idiomas.csv')
# Out:
# Guardado: D:\Proyecto_Tesis\data\processed\catalogo_idiomas.csv (4 filas x 2 columnas)
# WindowsPath('D:/Proyecto_Tesis/data/processed/catalogo_idiomas.csv')
