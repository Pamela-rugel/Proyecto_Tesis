# %% [markdown]
# # 06. Certificados (todos)
#
# Proyecto de tesis (Maestria en Ciencia de Datos e IA, ESPOL): *Sistema de Generacion de Perfiles del Personal Docente y Administrativo en ESPOL para la asignacion inteligente de tareas*. Este notebook corresponde a la **Fase 1 y 2** de la metodologia: extraccion y depuracion de una de las fuentes institucionales que alimentan el catalogo de variables (historia laboral, capacitaciones, proyectos, experiencia y direcciones de tesis) usado para construir los perfiles multidimensionales del personal.
#
# **Fuente:** `data/raw/certificadostodos.csv`
# **Salida:** `data/processed/certificados_todos.csv`
#
# Certificaciones obtenidas por el personal (subconjunto de capacitaciones con TIPOEVENTODESCRIPCION = CERTIFICACION). Comparte esquema con capacitaciones_todas y ponentes_todos.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd()))
import pandas as pd
import _preprocesamiento_comun as pc

pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## 1. Carga de datos crudos

# %%
df = pc.leer_csv('certificadostodos.csv', low_memory=False)
df.head()
# Out:
# Leido certificadostodos.csv con encoding=utf-8-sig -> 5096 filas, 62 columnas
#   TIPODESCRIPCION AREAACITACIONDESCRIPCION TIPOMODALIDADDESCRIPCION  \
# 0             NaN                      NaN                  VIRTUAL
# 1             NaN                      NaN                  VIRTUAL
# 2      APROBACION                      NaN                  VIRTUAL
# 3      APROBACION                      NaN                  VIRTUAL
# 4      APROBACION                      NaN                  VIRTUAL
#
#   TIPOEVENTODESCRIPCION NOMBREPAIS  IDCAPACITACION  IDPERSONA  \
# 0         CERTIFICACIÓN        NaN           76984     646197
# 1         CERTIFICACIÓN        NaN           72412      51391
# 2         CERTIFICACIÓN        NaN           48180      75823
# 3         CERTIFICACIÓN        NaN           48181      75823
# 4         CERTIFICACIÓN        NaN           48182      75823
#
#                                             NOMBRE  DURACION FECHAINICIO  \
# 0  DIPLOMADO EN EDUCACIÓN INCLUSIVA Y DISCAPACIDAD      49.0  2025-06-05
# 1                     •\tEFFECTIVE EDUCATOR IPEER        5.0  2025-11-12
# 2                 Process Data from Dirty to Clean      40.0  2021-12-01
# 3                     Prepare Data for Exploration      40.0  2021-11-07
# 4      Ask Questions to Make Data-Driven Decisions      40.0  2021-10-21
#
#      FECHAFIN  LUGARREALIZACION TIPOCERTIFICADO TIPOCAPACITACION  COSTO  \
# 0  2030-06-05               NaN             NaN              NaN    NaN
# 1  2029-11-03               NaN             NaN              NaN    NaN
# 2  2021-12-18               NaN              AP              NaN    NaN
# 3  2021-11-23               NaN              AP              NaN    NaN
# 4  2021-11-06               NaN              AP              NaN    NaN
#
#    AREAAPLICACION  INSTITUCION  TIPOINSTITUCION  PUNTAJEOBTENIDO  \
# 0             NaN          NaN              NaN              NaN
# 1             NaN          NaN              NaN              NaN
# 2             NaN          NaN              NaN              NaN
# 3             NaN          NaN              NaN              NaN
# 4             NaN          NaN              NaN              NaN
#
#                 ULTIMO_CAMBIO FECHAASCENSO  IDPAIS  IDCIUDAD  GRADOCATEGORIA  \
# 0  2026-03-22-21.34.21.008193   2026-03-22       0       NaN             NaN
# 1  2026-04-21-14.30.16.771872   2025-12-07       0       NaN             NaN
# 2  2022-04-18-13.19.54.375338   2022-04-18       0       NaN             NaN
# 3  2022-04-18-13.22.41.414193   2022-04-18       0       NaN             NaN
# 4  2022-04-18-13.25.16.008481   2022-04-18       0       NaN             NaN
#
#    ANIO  TERMINO  IDAREA  ENTREGADO  IDINSTITUCION  TIPOPARTICIPACION MODULO  \
# 0   NaN      NaN     NaN        NaN            0.0                NaN      D
# 1   NaN      NaN     NaN        NaN            0.0                NaN      D
# 2   NaN      NaN     NaN        NaN            0.0                NaN      D
# 3   NaN      NaN     NaN        NaN            0.0                NaN      D
# 4   NaN      NaN     NaN        NaN            0.0                NaN      D
#
#    TIPOEVENTO  AUSPICIANTE  DURACIONHORAS  NACIONALIDAD  \
# 0          22          NaN            NaN           NaN
# 1          22          NaN            NaN           NaN
# 2          22          NaN            NaN           NaN
# 3          22          NaN            NaN           NaN
# 4          22          NaN            NaN           NaN
#
#                                       CERTIFICADOPOR NAMEARCHDOC FORMACONOCIM  \
# 0                        UNIVERSIDAD DE LAS AMERICAS         NaN          R
# 1  ENGINEERING EDUCATOR, INTERNATIONAL PROFESSION...         NaN          R
# 2                                             GOOGLE         NaN          R
# 3                                             GOOGLE         NaN          R
# 4                                             GOOGLE         NaN          R
#
#    IDTIPOCONOCIMIEN REVISADOPARAESCALAFON ENESCALAFON  NAMEARCHDOC2  \
# 0               NaN                     N           N           NaN
# 1               NaN                     N           N           NaN
# 2               2.0                     N           N           NaN
# 3               2.0                     N           N           NaN
# 4               2.0                     N           N           NaN
#
#    NAMEARCHDOC3 CONSIDERACOMISANT  NAMEDOCCOMISANT      REFARCHIVO1  \
# 0           NaN                 N              NaN  2127775,2010564
# 1           NaN                 N              NaN  1953874,1844383
# 2           NaN                 N              NaN    693547,652508
# 3           NaN                 N              NaN    693550,652511
# 4           NaN                 N              NaN    693551,652512
#
#   REFARCHIVO2 REFARCHIVO3  REFARCHIVO4 INGRESORRHH  IDUSUARIO  \
# 0         NaN         NaN          NaN           N        NaN
# 1         NaN         NaN          NaN           N   651029.0
# 2         NaN         NaN          NaN           N        NaN
# 3         NaN         NaN          NaN           N        NaN
# 4         NaN         NaN          NaN           N        NaN
#
#    IDREGISTROESCALAFONAPROB FECHACHECKESCALAFON TIPOMODALIDAD  \
# 0                       NaN                 NaN             L
# 1                       NaN                 NaN             L
# 2                       NaN                 NaN             L
# 3                       NaN                 NaN             L
# 4                       NaN                 NaN             L
#
#   GESTIONUATHESPOL  IDCANTON ORIGENINGRESO          FECHASUBIDAARCHIVO  \
# 0                N       NaN           NaN  2026-03-22-21.34.21.305708
# 1                N       NaN           NaN  2025-12-07-19.58.56.677706
# 2                N       NaN           WEB                         NaN
# 3                N       NaN           WEB                         NaN
# 4                N       NaN           WEB                         NaN
#
#   REFARCHIVOSENESCYT FECHASUBIDAARCHIVOSENESCYT  ESTADOAPROBACION  \
# 0                NaN                        NaN               NaN
# 1                NaN                        NaN               2.0
# 2                NaN                        NaN               NaN
# 3                NaN                        NaN               NaN
# 4                NaN                        NaN               NaN
#
#               FECHAAPROBACION
# 0                         NaN
# 1  2026-04-21-14.30.16.771872
# 2                         NaN
# 3                         NaN
# 4                         NaN

# %% [markdown]
# ## 2. Exploración inicial

# %%
pc.resumen(df, 'certificados_todos')
# Out:
# --- Resumen certificados_todos ---
# Dimensiones: 5096 filas x 62 columnas
# Filas duplicadas: 0
# Columnas con nulos (%):
# LUGARREALIZACION              100.0
# PUNTAJEOBTENIDO               100.0
# TIPOINSTITUCION               100.0
# IDAREA                        100.0
# ENTREGADO                     100.0
# TIPOPARTICIPACION             100.0
# GRADOCATEGORIA                100.0
# ANIO                          100.0
# TERMINO                       100.0
# COSTO                         100.0
# AREAAPLICACION                100.0
# INSTITUCION                   100.0
# AUSPICIANTE                   100.0
# DURACIONHORAS                 100.0
# REFARCHIVO4                   100.0
# IDREGISTROESCALAFONAPROB      100.0
# NAMEDOCCOMISANT               100.0
# NAMEARCHDOC3                  100.0
# NAMEARCHDOC2                  100.0
# NACIONALIDAD                  100.0
# REFARCHIVO3                   100.0
# REFARCHIVO2                    99.9
# TIPOCAPACITACION               99.9
# NAMEARCHDOC                    99.9
# AREAACITACIONDESCRIPCION       99.9
# FECHACHECKESCALAFON            99.4
# REFARCHIVOSENESCYT             97.5
# FECHASUBIDAARCHIVOSENESCYT     97.1
# IDCANTON                       96.2
# IDCIUDAD                       95.4
# ESTADOAPROBACION               93.2
# FECHAAPROBACION                93.2
# ORIGENINGRESO                  86.0
# IDUSUARIO                      85.4
# FECHASUBIDAARCHIVO             78.4
# TIPOCERTIFICADO                20.8
# TIPODESCRIPCION                20.8
# IDTIPOCONOCIMIEN               20.8
# TIPOMODALIDADDESCRIPCION        3.5
# NOMBREPAIS                      2.6
# IDINSTITUCION                   2.4
# CONSIDERACOMISANT               2.4
# TIPOMODALIDAD                   2.2
# REVISADOPARAESCALAFON           2.2
# ENESCALAFON                     2.2
# REFARCHIVO1                     0.7
# CERTIFICADOPOR                  0.3
# dtype: float64

# %%
df.dtypes
# Out:
# TIPODESCRIPCION                   str
# AREAACITACIONDESCRIPCION          str
# TIPOMODALIDADDESCRIPCION          str
# TIPOEVENTODESCRIPCION             str
# NOMBREPAIS                        str
#                                ...
# FECHASUBIDAARCHIVO                str
# REFARCHIVOSENESCYT                str
# FECHASUBIDAARCHIVOSENESCYT        str
# ESTADOAPROBACION              float64
# FECHAAPROBACION                   str
# Length: 62, dtype: object

# %% [markdown]
# ## 3. Limpieza

# %%
df = pc.limpiar_strings(df)
df = pc.quitar_columnas_vacias(df, umbral=0.99)
df = pc.quitar_columnas_constantes(df)
# Out:
# Columnas eliminadas por tener >= 99% de nulos: ['AREAACITACIONDESCRIPCION', 'LUGARREALIZACION', 'TIPOCAPACITACION', 'COSTO', 'AREAAPLICACION', 'INSTITUCION', 'TIPOINSTITUCION', 'PUNTAJEOBTENIDO', 'GRADOCATEGORIA', 'ANIO', 'TERMINO', 'IDAREA', 'ENTREGADO', 'TIPOPARTICIPACION', 'AUSPICIANTE', 'DURACIONHORAS', 'NACIONALIDAD', 'NAMEARCHDOC', 'NAMEARCHDOC2', 'NAMEARCHDOC3', 'NAMEDOCCOMISANT', 'REFARCHIVO2', 'REFARCHIVO3', 'REFARCHIVO4', 'IDREGISTROESCALAFONAPROB', 'FECHACHECKESCALAFON']
# Columnas eliminadas por ser constantes: ['TIPOEVENTODESCRIPCION', 'IDINSTITUCION', 'MODULO', 'TIPOEVENTO', 'FORMACONOCIM', 'REVISADOPARAESCALAFON', 'CONSIDERACOMISANT', 'ESTADOAPROBACION']

# %% [markdown]
# ## 5. Tipado de fechas e identificadores

# %%
df = pc.castear_fechas(df, ['FECHAINICIO', 'FECHAFIN', 'ULTIMO_CAMBIO', 'FECHAASCENSO', 'FECHACHECKESCALAFON', 'FECHASUBIDAARCHIVO', 'FECHAAPROBACION'])
df = pc.castear_enteros(df, ['IDCAPACITACION', 'IDPERSONA', 'IDPAIS', 'IDCIUDAD', 'IDINSTITUCION', 'IDUSUARIO', 'IDCANTON', 'IDTIPOCONOCIMIEN'])

# %% [markdown]
# ## 7. Verificación final

# %%
pc.resumen(df, 'certificados_todos (procesado)')
df.head()
# Out:
# --- Resumen certificados_todos (procesado) ---
# Dimensiones: 5096 filas x 28 columnas
# Filas duplicadas: 0
# Columnas con nulos (%):
# REFARCHIVOSENESCYT            97.5
# FECHASUBIDAARCHIVOSENESCYT    97.1
# IDCANTON                      96.2
# IDCIUDAD                      95.4
# FECHAAPROBACION               93.2
# ORIGENINGRESO                 86.0
# IDUSUARIO                     85.4
# FECHASUBIDAARCHIVO            78.4
# TIPODESCRIPCION               20.8
# TIPOCERTIFICADO               20.8
# IDTIPOCONOCIMIEN              20.8
# TIPOMODALIDADDESCRIPCION       3.5
# NOMBREPAIS                     2.6
# TIPOMODALIDAD                  2.2
# ENESCALAFON                    2.2
# REFARCHIVO1                    0.7
# CERTIFICADOPOR                 0.3
# dtype: float64
#   TIPODESCRIPCION TIPOMODALIDADDESCRIPCION NOMBREPAIS  IDCAPACITACION  \
# 0            <NA>                  VIRTUAL       <NA>           76984
# 1            <NA>                  VIRTUAL       <NA>           72412
# 2      APROBACION                  VIRTUAL       <NA>           48180
# 3      APROBACION                  VIRTUAL       <NA>           48181
# 4      APROBACION                  VIRTUAL       <NA>           48182
#
#    IDPERSONA                                           NOMBRE  DURACION  \
# 0     646197  DIPLOMADO EN EDUCACIÓN INCLUSIVA Y DISCAPACIDAD      49.0
# 1      51391                      •\tEFFECTIVE EDUCATOR IPEER       5.0
# 2      75823                 Process Data from Dirty to Clean      40.0
# 3      75823                     Prepare Data for Exploration      40.0
# 4      75823      Ask Questions to Make Data-Driven Decisions      40.0
#
#   FECHAINICIO   FECHAFIN TIPOCERTIFICADO              ULTIMO_CAMBIO  \
# 0  2025-06-05 2030-06-05            <NA> 2026-03-22 21:34:21.008193
# 1  2025-11-12 2029-11-03            <NA> 2026-04-21 14:30:16.771872
# 2  2021-12-01 2021-12-18              AP 2022-04-18 13:19:54.375338
# 3  2021-11-07 2021-11-23              AP 2022-04-18 13:22:41.414193
# 4  2021-10-21 2021-11-06              AP 2022-04-18 13:25:16.008481
#
#   FECHAASCENSO  IDPAIS  IDCIUDAD  \
# 0   2026-03-22       0      <NA>
# 1   2025-12-07       0      <NA>
# 2   2022-04-18       0      <NA>
# 3   2022-04-18       0      <NA>
# 4   2022-04-18       0      <NA>
#
#                                       CERTIFICADOPOR  IDTIPOCONOCIMIEN  \
# 0                        UNIVERSIDAD DE LAS AMERICAS              <NA>
# 1  ENGINEERING EDUCATOR, INTERNATIONAL PROFESSION...              <NA>
# 2                                             GOOGLE                 2
# 3                                             GOOGLE                 2
# 4                                             GOOGLE                 2
#
#   ENESCALAFON      REFARCHIVO1 INGRESORRHH  IDUSUARIO TIPOMODALIDAD  \
# 0           N  2127775,2010564           N       <NA>             L
# 1           N  1953874,1844383           N     651029             L
# 2           N    693547,652508           N       <NA>             L
# 3           N    693550,652511           N       <NA>             L
# 4           N    693551,652512           N       <NA>             L
#
#   GESTIONUATHESPOL  IDCANTON ORIGENINGRESO         FECHASUBIDAARCHIVO  \
# 0                N      <NA>          <NA> 2026-03-22 21:34:21.305708
# 1                N      <NA>          <NA> 2025-12-07 19:58:56.677706
# 2                N      <NA>           WEB                        NaT
# 3                N      <NA>           WEB                        NaT
# 4                N      <NA>           WEB                        NaT
#
#   REFARCHIVOSENESCYT FECHASUBIDAARCHIVOSENESCYT            FECHAAPROBACION
# 0               <NA>                       <NA>                        NaT
# 1               <NA>                       <NA> 2026-04-21 14:30:16.771872
# 2               <NA>                       <NA>                        NaT
# 3               <NA>                       <NA>                        NaT
# 4               <NA>                       <NA>                        NaT

# %% [markdown]
# ## 8. Guardado en data/processed

# %%
pc.guardar_procesado(df, 'certificados_todos.csv')
# Out:
# Guardado: D:\Proyecto_Tesis\data\processed\certificados_todos.csv (5096 filas x 28 columnas)
# WindowsPath('D:/Proyecto_Tesis/data/processed/certificados_todos.csv')
