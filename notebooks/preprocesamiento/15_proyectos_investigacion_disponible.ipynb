# %% [markdown]
# # 15. Proyectos de investigación disponibles
#
# Proyecto de tesis (Maestria en Ciencia de Datos e IA, ESPOL): *Sistema de Generacion de Perfiles del Personal Docente y Administrativo en ESPOL para la asignacion inteligente de tareas*. Este notebook corresponde a la **Fase 1 y 2** de la metodologia: extraccion y depuracion de una de las fuentes institucionales que alimentan el catalogo de variables (historia laboral, capacitaciones, proyectos, experiencia y direcciones de tesis) usado para construir los perfiles multidimensionales del personal.
#
# **Fuente:** `data/raw/proyectosinvestigaciondisponible.csv`
# **Salida:** `data/processed/proyectos_investigacion_disponible.csv`
#
# Proyectos de investigacion en los que ha participado el personal (tipo, institucion, area de conocimiento, rol, financiamiento).

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd()))
import pandas as pd
import _preprocesamiento_comun as pc

pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## 1. Carga de datos crudos

# %%
df = pc.leer_csv('proyectosinvestigaciondisponible.csv', low_memory=False)
df.head()
# Out:
# Leido proyectosinvestigaciondisponible.csv con encoding=utf-8-sig -> 6768 filas, 51 columnas
#    IDPROYECTOINVESTIGACION TIPO  SUBTIPO  \
# 0                     3100    I        2
# 1                     5694    I        3
# 2                     3100    I        2
# 3                     5694    I        3
# 4                     5694    I        3
#
#                                               NOMBRE  \
# 0  DESEMPEÑO AMBIENTAL DEL CEMENTO Y EL CONCRETO ...
# 1  RECOMP–RECYCLED COMPOSITES FOR ENGINEERING, DE...
# 2  DESEMPEÑO AMBIENTAL DEL CEMENTO Y EL CONCRETO ...
# 3  RECOMP–RECYCLED COMPOSITES FOR ENGINEERING, DE...
# 4  RECOMP–RECYCLED COMPOSITES FOR ENGINEERING, DE...
#
#                   FECHAINICIO                    FECHAFIN  IDPAIS  \
# 0  2020-05-03-00.00.00.000000  2024-06-30-00.00.00.000000       1
# 1  2026-02-02-00.00.00.000000  2028-02-18-00.00.00.000000       1
# 2  2020-05-03-00.00.00.000000  2024-06-30-00.00.00.000000       1
# 3  2026-02-02-00.00.00.000000  2028-02-18-00.00.00.000000       1
# 4  2026-02-02-00.00.00.000000  2028-02-18-00.00.00.000000       1
#
#         INSTITUCION_EXTERNA  \
# 0                    HOLCIM
# 1  UNIVERSIDAD DE GUAYAQUIL
# 2                    HOLCIM
# 3  UNIVERSIDAD DE GUAYAQUIL
# 4  UNIVERSIDAD DE GUAYAQUIL
#
#                                    INSTITUCION_ESPOL  IDPERSONA  \
# 0  FACULTAD DE INGENIERÍA EN MECÁNICA Y CIENCIAS ...       1178
# 1  FACULTAD DE INGENIERÍA EN MECÁNICA Y CIENCIAS ...     674686
# 2  FACULTAD DE INGENIERÍA EN MECÁNICA Y CIENCIAS ...      73715
# 3  FACULTAD DE INGENIERÍA EN MECÁNICA Y CIENCIAS ...      55753
# 4  FACULTAD DE INGENIERÍA EN MECÁNICA Y CIENCIAS ...       1586
#
#    IDROLPROYECTO  IDNOMENCLATURATIT  IDNOMENCLATURATIT2  IDAREACONOCIM  \
# 0              1              314.0               460.0              8
# 1              4              267.0               267.0              8
# 2              4              314.0               460.0              8
# 3              1              267.0               267.0              8
# 4              4              267.0               267.0              8
#
#    IDSUBAREACONOC  IDAREACONOCIM2  IDSUBAREACONOC2  IDAREAFRASCATI  \
# 0               2               6                2               2
# 1               1               8                1               2
# 2               2               6                2               2
# 3               1               8                1               2
# 4               1               8                1               2
#
#    IDSUBAREAFRASCATI  IDAREAFRASCATI2  IDSUBAREAFRASCATI2  \
# 0                  7                2                   5
# 1                  3                2                   5
# 2                  7                2                   5
# 3                  3                2                   5
# 4                  3                2                   5
#
#                                        RESPONSFINANC ENESCALAFON  \
# 0  MAESTRÍA ECOEFICIENCIA INDUSTRIAL (PAGO A DIRE...         NaN
# 1                                              ESPOL         NaN
# 2  MAESTRÍA ECOEFICIENCIA INDUSTRIAL (PAGO A DIRE...         NaN
# 3                                              ESPOL         NaN
# 4                                              ESPOL         NaN
#
#                                          REFARCHIVO1  \
# 0  https://gestionproyectos.espol.edu.ec/UPLOADS/...
# 1  https://gestionproyectos.espol.edu.ec/UPLOADS/...
# 2  https://gestionproyectos.espol.edu.ec/UPLOADS/...
# 3  https://gestionproyectos.espol.edu.ec/UPLOADS/...
# 4  https://gestionproyectos.espol.edu.ec/UPLOADS/...
#
#                                          REFARCHIVO2  \
# 0  https://gestionproyectos.espol.edu.ec/UPLOADS/...
# 1                                                NaN
# 2  https://gestionproyectos.espol.edu.ec/UPLOADS/...
# 3                                                NaN
# 4                                                NaN
#
#                                          REFARCHIVO3          ESTADO_PROYECTO  \
# 0                                                NaN               FINALIZADO
# 1  https://gestionproyectos.espol.edu.ec/UPLOADS/...  APROBADO Y EN EJECUCIÓN
# 2                                                NaN               FINALIZADO
# 3  https://gestionproyectos.espol.edu.ec/UPLOADS/...  APROBADO Y EN EJECUCIÓN
# 4  https://gestionproyectos.espol.edu.ec/UPLOADS/...  APROBADO Y EN EJECUCIÓN
#
#   TABLA               ULTIMO_CAMBIO   ROLPROYECTO  TIPOFINANCIAMIENTOEXTERNO  \
# 0     I  2024-01-17-11.49.14.289970      DIRECTOR                          0
# 1     I  2026-04-23-13.43.31.483729   CO-DIRECTOR                          0
# 2     I  2024-01-17-11.49.14.289970  PARTICIPANTE                          0
# 3     I  2026-04-23-13.43.31.483729      DIRECTOR                          0
# 4     I  2026-04-23-13.43.31.483729  PARTICIPANTE                          0
#
#       STRSISTEMA  STRPAIS        STRTIPO  STRSUBTIPO  \
# 0  INVESTIGACION  ECUADOR  Investigacion    Aplicada
# 1  INVESTIGACION  ECUADOR  Investigacion  Desarrollo
# 2  INVESTIGACION  ECUADOR  Investigacion    Aplicada
# 3  INVESTIGACION  ECUADOR  Investigacion  Desarrollo
# 4  INVESTIGACION  ECUADOR  Investigacion  Desarrollo
#
#                      STRAREACAMPOAMPLIO           STRAREACAMPOESPECIFICO  \
# 0  Ingeniería, industria y construcción           Industria y producción
# 1  Ingeniería, industria y construcción  Ingeniería y profesiones afines
# 2  Ingeniería, industria y construcción           Industria y producción
# 3  Ingeniería, industria y construcción  Ingeniería y profesiones afines
# 4  Ingeniería, industria y construcción  Ingeniería y profesiones afines
#
#    STRAREACAMPODETALLADO  STRCAMPOAMPLIO  STRCAMPOESPECIFICO  \
# 0                    NaN             7.0                 2.0
# 1                    NaN             7.0                 1.0
# 2                    NaN             7.0                 2.0
# 3                    NaN             7.0                 1.0
# 4                    NaN             7.0                 1.0
#
#    STRCAMPODETALLADO                            STRAREACAMPOAMPLIO2  \
# 0                0.0  Ciencias naturales, matemáticas y estadística
# 1                0.0           Ingeniería, industria y construcción
# 2                0.0  Ciencias naturales, matemáticas y estadística
# 3                0.0           Ingeniería, industria y construcción
# 4                0.0           Ingeniería, industria y construcción
#
#            STRAREACAMPOESPECIFICO2  STRAREACAMPODETALLADO2  STRCAMPOAMPLIO2  \
# 0                   Medio ambiente                     NaN              5.0
# 1  Ingeniería y profesiones afines                     NaN              7.0
# 2                   Medio ambiente                     NaN              5.0
# 3  Ingeniería y profesiones afines                     NaN              7.0
# 4  Ingeniería y profesiones afines                     NaN              7.0
#
#    STRCAMPOESPECIFICO2  STRCAMPODETALLADO2             STRAREAFRASCATI  \
# 0                  2.0                 0.0  Engineering and Technology
# 1                  1.0                 0.0  Engineering and Technology
# 2                  2.0                 0.0  Engineering and Technology
# 3                  1.0                 0.0  Engineering and Technology
# 4                  1.0                 0.0  Engineering and Technology
#
#           STRSUBAREAFRASCATI            STRAREAFRASCATI2  \
# 0  Environmental engineering  Engineering and Technology
# 1     Mechanical engineering  Engineering and Technology
# 2  Environmental engineering  Engineering and Technology
# 3     Mechanical engineering  Engineering and Technology
# 4     Mechanical engineering  Engineering and Technology
#
#      STRSUBAREAFRASCATI2
# 0  Materials engineering
# 1  Materials engineering
# 2  Materials engineering
# 3  Materials engineering
# 4  Materials engineering

# %% [markdown]
# ## 2. Exploración inicial

# %%
pc.resumen(df, 'proyectos_investigacion_disponible')
# Out:
# --- Resumen proyectos_investigacion_disponible ---
# Dimensiones: 6768 filas x 51 columnas
# Filas duplicadas: 0
# Columnas con nulos (%):
# STRAREACAMPODETALLADO2     100.0
# STRAREACAMPODETALLADO      100.0
# ENESCALAFON                 96.7
# STRSUBAREAFRASCATI2         87.9
# STRAREAFRASCATI2            87.9
# STRAREACAMPOAMPLIO2         84.9
# STRAREACAMPOESPECIFICO2     84.9
# STRCAMPOAMPLIO2             84.9
# IDNOMENCLATURATIT2          84.9
# STRCAMPOESPECIFICO2         84.9
# STRCAMPODETALLADO2          84.9
# REFARCHIVO3                 55.6
# REFARCHIVO2                 45.7
# REFARCHIVO1                 38.6
# INSTITUCION_EXTERNA         35.8
# INSTITUCION_ESPOL            2.3
# IDNOMENCLATURATIT            1.3
# STRCAMPOAMPLIO               1.3
# STRCAMPOESPECIFICO           1.3
# STRAREACAMPOAMPLIO           1.3
# STRCAMPODETALLADO            1.3
# STRAREACAMPOESPECIFICO       1.3
# STRSUBTIPO                   0.3
# RESPONSFINANC                0.1
# dtype: float64

# %%
df.dtypes
# Out:
# IDPROYECTOINVESTIGACION        int64
# TIPO                             str
# SUBTIPO                        int64
# NOMBRE                           str
# FECHAINICIO                      str
# FECHAFIN                         str
# IDPAIS                         int64
# INSTITUCION_EXTERNA              str
# INSTITUCION_ESPOL                str
# IDPERSONA                      int64
# IDROLPROYECTO                  int64
# IDNOMENCLATURATIT            float64
# IDNOMENCLATURATIT2           float64
# IDAREACONOCIM                  int64
# IDSUBAREACONOC                 int64
# IDAREACONOCIM2                 int64
# IDSUBAREACONOC2                int64
# IDAREAFRASCATI                 int64
# IDSUBAREAFRASCATI              int64
# IDAREAFRASCATI2                int64
# IDSUBAREAFRASCATI2             int64
# RESPONSFINANC                    str
# ENESCALAFON                      str
# REFARCHIVO1                      str
# REFARCHIVO2                      str
# REFARCHIVO3                      str
# ESTADO_PROYECTO                  str
# TABLA                            str
# ULTIMO_CAMBIO                    str
# ROLPROYECTO                      str
# TIPOFINANCIAMIENTOEXTERNO      int64
# STRSISTEMA                       str
# STRPAIS                          str
# STRTIPO                          str
# STRSUBTIPO                       str
# STRAREACAMPOAMPLIO               str
# STRAREACAMPOESPECIFICO           str
# STRAREACAMPODETALLADO        float64
# STRCAMPOAMPLIO               float64
# STRCAMPOESPECIFICO           float64
# STRCAMPODETALLADO            float64
# STRAREACAMPOAMPLIO2              str
# STRAREACAMPOESPECIFICO2          str
# STRAREACAMPODETALLADO2       float64
# STRCAMPOAMPLIO2              float64
# STRCAMPOESPECIFICO2          float64
# STRCAMPODETALLADO2           float64
# STRAREAFRASCATI                  str
# STRSUBAREAFRASCATI               str
# STRAREAFRASCATI2                 str
# STRSUBAREAFRASCATI2              str
# dtype: object

# %% [markdown]
# ## 3. Limpieza

# %%
df = pc.limpiar_strings(df)
df = pc.quitar_columnas_vacias(df, umbral=0.99)
df = pc.quitar_columnas_constantes(df)
# Out:
# Columnas eliminadas por tener >= 99% de nulos: ['STRAREACAMPODETALLADO', 'STRAREACAMPODETALLADO2']
# Columnas eliminadas por ser constantes: ['TABLA', 'STRSISTEMA', 'STRCAMPODETALLADO', 'STRCAMPODETALLADO2']

# %% [markdown]
# ## 5. Tipado de fechas e identificadores

# %%
df = pc.castear_fechas(df, ['FECHAINICIO', 'FECHAFIN', 'ULTIMO_CAMBIO'])
df = pc.castear_enteros(df, ['IDPROYECTOINVESTIGACION', 'IDPERSONA', 'IDPAIS', 'IDROLPROYECTO', 'IDNOMENCLATURATIT', 'IDNOMENCLATURATIT2', 'IDAREACONOCIM', 'IDSUBAREACONOC', 'IDAREACONOCIM2', 'IDSUBAREACONOC2', 'IDAREAFRASCATI', 'IDSUBAREAFRASCATI', 'IDAREAFRASCATI2', 'IDSUBAREAFRASCATI2'])

# %% [markdown]
# ## 7. Verificación final

# %%
pc.resumen(df, 'proyectos_investigacion_disponible (procesado)')
df.head()
# Out:
# --- Resumen proyectos_investigacion_disponible (procesado) ---
# Dimensiones: 6768 filas x 45 columnas
# Filas duplicadas: 0
# Columnas con nulos (%):
# ENESCALAFON                96.7
# STRSUBAREAFRASCATI2        87.9
# STRAREAFRASCATI2           87.9
# STRAREACAMPOESPECIFICO2    84.9
# IDNOMENCLATURATIT2         84.9
# STRCAMPOAMPLIO2            84.9
# STRCAMPOESPECIFICO2        84.9
# STRAREACAMPOAMPLIO2        84.9
# REFARCHIVO3                55.6
# REFARCHIVO2                45.7
# REFARCHIVO1                38.6
# INSTITUCION_EXTERNA        35.8
# INSTITUCION_ESPOL           2.3
# STRAREACAMPOESPECIFICO      1.3
# IDNOMENCLATURATIT           1.3
# STRCAMPOAMPLIO              1.3
# STRCAMPOESPECIFICO          1.3
# STRAREACAMPOAMPLIO          1.3
# STRSUBTIPO                  0.3
# RESPONSFINANC               0.1
# dtype: float64
#    IDPROYECTOINVESTIGACION TIPO  SUBTIPO  \
# 0                     3100    I        2
# 1                     5694    I        3
# 2                     3100    I        2
# 3                     5694    I        3
# 4                     5694    I        3
#
#                                               NOMBRE FECHAINICIO   FECHAFIN  \
# 0  DESEMPEÑO AMBIENTAL DEL CEMENTO Y EL CONCRETO ...  2020-05-03 2024-06-30
# 1  RECOMP–RECYCLED COMPOSITES FOR ENGINEERING, DE...  2026-02-02 2028-02-18
# 2  DESEMPEÑO AMBIENTAL DEL CEMENTO Y EL CONCRETO ...  2020-05-03 2024-06-30
# 3  RECOMP–RECYCLED COMPOSITES FOR ENGINEERING, DE...  2026-02-02 2028-02-18
# 4  RECOMP–RECYCLED COMPOSITES FOR ENGINEERING, DE...  2026-02-02 2028-02-18
#
#    IDPAIS       INSTITUCION_EXTERNA  \
# 0       1                    HOLCIM
# 1       1  UNIVERSIDAD DE GUAYAQUIL
# 2       1                    HOLCIM
# 3       1  UNIVERSIDAD DE GUAYAQUIL
# 4       1  UNIVERSIDAD DE GUAYAQUIL
#
#                                    INSTITUCION_ESPOL  IDPERSONA  \
# 0  FACULTAD DE INGENIERÍA EN MECÁNICA Y CIENCIAS ...       1178
# 1  FACULTAD DE INGENIERÍA EN MECÁNICA Y CIENCIAS ...     674686
# 2  FACULTAD DE INGENIERÍA EN MECÁNICA Y CIENCIAS ...      73715
# 3  FACULTAD DE INGENIERÍA EN MECÁNICA Y CIENCIAS ...      55753
# 4  FACULTAD DE INGENIERÍA EN MECÁNICA Y CIENCIAS ...       1586
#
#    IDROLPROYECTO  IDNOMENCLATURATIT  IDNOMENCLATURATIT2  IDAREACONOCIM  \
# 0              1                314                 460              8
# 1              4                267                 267              8
# 2              4                314                 460              8
# 3              1                267                 267              8
# 4              4                267                 267              8
#
#    IDSUBAREACONOC  IDAREACONOCIM2  IDSUBAREACONOC2  IDAREAFRASCATI  \
# 0               2               6                2               2
# 1               1               8                1               2
# 2               2               6                2               2
# 3               1               8                1               2
# 4               1               8                1               2
#
#    IDSUBAREAFRASCATI  IDAREAFRASCATI2  IDSUBAREAFRASCATI2  \
# 0                  7                2                   5
# 1                  3                2                   5
# 2                  7                2                   5
# 3                  3                2                   5
# 4                  3                2                   5
#
#                                        RESPONSFINANC ENESCALAFON  \
# 0  MAESTRÍA ECOEFICIENCIA INDUSTRIAL (PAGO A DIRE...        <NA>
# 1                                              ESPOL        <NA>
# 2  MAESTRÍA ECOEFICIENCIA INDUSTRIAL (PAGO A DIRE...        <NA>
# 3                                              ESPOL        <NA>
# 4                                              ESPOL        <NA>
#
#                                          REFARCHIVO1  \
# 0  https://gestionproyectos.espol.edu.ec/UPLOADS/...
# 1  https://gestionproyectos.espol.edu.ec/UPLOADS/...
# 2  https://gestionproyectos.espol.edu.ec/UPLOADS/...
# 3  https://gestionproyectos.espol.edu.ec/UPLOADS/...
# 4  https://gestionproyectos.espol.edu.ec/UPLOADS/...
#
#                                          REFARCHIVO2  \
# 0  https://gestionproyectos.espol.edu.ec/UPLOADS/...
# 1                                               <NA>
# 2  https://gestionproyectos.espol.edu.ec/UPLOADS/...
# 3                                               <NA>
# 4                                               <NA>
#
#                                          REFARCHIVO3          ESTADO_PROYECTO  \
# 0                                               <NA>               FINALIZADO
# 1  https://gestionproyectos.espol.edu.ec/UPLOADS/...  APROBADO Y EN EJECUCIÓN
# 2                                               <NA>               FINALIZADO
# 3  https://gestionproyectos.espol.edu.ec/UPLOADS/...  APROBADO Y EN EJECUCIÓN
# 4  https://gestionproyectos.espol.edu.ec/UPLOADS/...  APROBADO Y EN EJECUCIÓN
#
#                ULTIMO_CAMBIO   ROLPROYECTO  TIPOFINANCIAMIENTOEXTERNO  \
# 0 2024-01-17 11:49:14.289970      DIRECTOR                          0
# 1 2026-04-23 13:43:31.483729   CO-DIRECTOR                          0
# 2 2024-01-17 11:49:14.289970  PARTICIPANTE                          0
# 3 2026-04-23 13:43:31.483729      DIRECTOR                          0
# 4 2026-04-23 13:43:31.483729  PARTICIPANTE                          0
#
#    STRPAIS        STRTIPO  STRSUBTIPO                    STRAREACAMPOAMPLIO  \
# 0  ECUADOR  Investigacion    Aplicada  Ingeniería, industria y construcción
# 1  ECUADOR  Investigacion  Desarrollo  Ingeniería, industria y construcción
# 2  ECUADOR  Investigacion    Aplicada  Ingeniería, industria y construcción
# 3  ECUADOR  Investigacion  Desarrollo  Ingeniería, industria y construcción
# 4  ECUADOR  Investigacion  Desarrollo  Ingeniería, industria y construcción
#
#             STRAREACAMPOESPECIFICO  STRCAMPOAMPLIO  STRCAMPOESPECIFICO  \
# 0           Industria y producción             7.0                 2.0
# 1  Ingeniería y profesiones afines             7.0                 1.0
# 2           Industria y producción             7.0                 2.0
# 3  Ingeniería y profesiones afines             7.0                 1.0
# 4  Ingeniería y profesiones afines             7.0                 1.0
#
#                              STRAREACAMPOAMPLIO2  \
# 0  Ciencias naturales, matemáticas y estadística
# 1           Ingeniería, industria y construcción
# 2  Ciencias naturales, matemáticas y estadística
# 3           Ingeniería, industria y construcción
# 4           Ingeniería, industria y construcción
#
#            STRAREACAMPOESPECIFICO2  STRCAMPOAMPLIO2  STRCAMPOESPECIFICO2  \
# 0                   Medio ambiente              5.0                  2.0
# 1  Ingeniería y profesiones afines              7.0                  1.0
# 2                   Medio ambiente              5.0                  2.0
# 3  Ingeniería y profesiones afines              7.0                  1.0
# 4  Ingeniería y profesiones afines              7.0                  1.0
#
#               STRAREAFRASCATI         STRSUBAREAFRASCATI  \
# 0  Engineering and Technology  Environmental engineering
# 1  Engineering and Technology     Mechanical engineering
# 2  Engineering and Technology  Environmental engineering
# 3  Engineering and Technology     Mechanical engineering
# 4  Engineering and Technology     Mechanical engineering
#
#              STRAREAFRASCATI2    STRSUBAREAFRASCATI2
# 0  Engineering and Technology  Materials engineering
# 1  Engineering and Technology  Materials engineering
# 2  Engineering and Technology  Materials engineering
# 3  Engineering and Technology  Materials engineering
# 4  Engineering and Technology  Materials engineering

# %% [markdown]
# ## 8. Guardado en data/processed

# %%
pc.guardar_procesado(df, 'proyectos_investigacion_disponible.csv')
# Out:
# Guardado: D:\Proyecto_Tesis\data\processed\proyectos_investigacion_disponible.csv (6768 filas x 45 columnas)
# WindowsPath('D:/Proyecto_Tesis/data/processed/proyectos_investigacion_disponible.csv')
