# %% [markdown]
# # 16. Proyectos de vinculación disponibles
#
# Proyecto de tesis (Maestria en Ciencia de Datos e IA, ESPOL): *Sistema de Generacion de Perfiles del Personal Docente y Administrativo en ESPOL para la asignacion inteligente de tareas*. Este notebook corresponde a la **Fase 1 y 2** de la metodologia: extraccion y depuracion de una de las fuentes institucionales que alimentan el catalogo de variables (historia laboral, capacitaciones, proyectos, experiencia y direcciones de tesis) usado para construir los perfiles multidimensionales del personal.
#
# **Fuente:** `data/raw/proyectosvinculaciondisponible.csv`
# **Salida:** `data/processed/proyectos_vinculacion_disponible.csv`
#
# Proyectos de vinculacion con la sociedad en los que ha participado el personal.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd()))
import pandas as pd
import _preprocesamiento_comun as pc

pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## 1. Carga de datos crudos

# %%
df = pc.leer_csv('proyectosvinculaciondisponible.csv', low_memory=False)
df.head()
# Out:
# Leido proyectosvinculaciondisponible.csv con encoding=utf-8-sig -> 2659 filas, 17 columnas
#    IDPERSONA  IDPROYECTOINVESTIGACION  \
# 0       1252                      225
# 1       2283                      217
# 2       2283                      213
# 3       2701                      222
# 4       2701                      226
#
#                                       NOMBREPROYECTO  \
# 0  Diseño e implementación de un sistema de infor...
# 1  Fortalecimiento a comunidades del Golfo de Gua...
# 2  Implementación de un Plan Piloto de Comerciali...
# 3    Centro de Atención Gratuita. (Gastos Generales)
# 4  Fortalecimiento de microempresas a través del ...
#
#                                       NOMBREPROGRAMA TIPO IDAREACONOCIM  \
# 0                            Excelencia Hospitalaria    V           NaN
# 1  Fortalecimiento de las capacidades de manejo y...    V           NaN
# 2  Fortalecimiento de las capacidades de manejo y...    V           NaN
# 3                        Centro de Atención Gratuita    V           NaN
# 4                        Centro de Atención Gratuita    V           NaN
#
#   FECHAINICIO FECHAFIN                                        REFARCHIVO1  \
# 0         NaN      NaN  https://practicas.espol.edu.ec/Proyecto/Proyec...
# 1         NaN      NaN  https://practicas.espol.edu.ec/Proyecto/Proyec...
# 2         NaN      NaN  https://practicas.espol.edu.ec/Proyecto/Proyec...
# 3         NaN      NaN  https://practicas.espol.edu.ec/Proyecto/Proyec...
# 4         NaN      NaN  https://practicas.espol.edu.ec/Proyecto/Proyec...
#
#    REFARCHIVO2  REFARCHIVO3           ROLPROYECTO TABLA  REVISADOENESCALAFON  \
# 0          NaN          NaN  DIRECTOR DE PROYECTO     V                  NaN
# 1          NaN          NaN  DIRECTOR DE PROGRAMA     V                  NaN
# 2          NaN          NaN  DIRECTOR DE PROYECTO     V                  NaN
# 3          NaN          NaN  DIRECTOR DE PROGRAMA     V                  NaN
# 4          NaN          NaN  DIRECTOR DE PROGRAMA     V                  NaN
#
#   ENESCALAFON  ESTIMULO  IDVSPROYECTOCOL
# 0         NaN       NaN                0
# 1         NaN       NaN                0
# 2         NaN       NaN                0
# 3         NaN       NaN                0
# 4         NaN       NaN                0

# %% [markdown]
# ## 2. Exploración inicial

# %%
pc.resumen(df, 'proyectos_vinculacion_disponible')
# Out:
# --- Resumen proyectos_vinculacion_disponible ---
# Dimensiones: 2659 filas x 17 columnas
# Filas duplicadas: 0
# Columnas con nulos (%):
# REVISADOENESCALAFON    100.0
# REFARCHIVO3            100.0
# ESTIMULO               100.0
# REFARCHIVO2            100.0
# ENESCALAFON             99.7
# IDAREACONOCIM            6.8
# FECHAINICIO              2.1
# FECHAFIN                 2.0
# dtype: float64

# %%
df.dtypes
# Out:
# IDPERSONA                    int64
# IDPROYECTOINVESTIGACION      int64
# NOMBREPROYECTO                 str
# NOMBREPROGRAMA                 str
# TIPO                           str
# IDAREACONOCIM                  str
# FECHAINICIO                    str
# FECHAFIN                       str
# REFARCHIVO1                    str
# REFARCHIVO2                float64
# REFARCHIVO3                float64
# ROLPROYECTO                    str
# TABLA                          str
# REVISADOENESCALAFON        float64
# ENESCALAFON                    str
# ESTIMULO                   float64
# IDVSPROYECTOCOL              int64
# dtype: object

# %% [markdown]
# ## 3. Limpieza

# %%
df = pc.limpiar_strings(df)
df = pc.quitar_columnas_vacias(df, umbral=0.99)
df = pc.quitar_columnas_constantes(df)
# Out:
# Columnas eliminadas por tener >= 99% de nulos: ['REFARCHIVO2', 'REFARCHIVO3', 'REVISADOENESCALAFON', 'ENESCALAFON', 'ESTIMULO']
# Columnas eliminadas por ser constantes: ['TIPO', 'TABLA']

# %% [markdown]
# ## 5. Tipado de fechas e identificadores

# %%
df = pc.castear_fechas(df, ['FECHAINICIO', 'FECHAFIN'])
df = pc.castear_enteros(df, ['IDPERSONA', 'IDPROYECTOINVESTIGACION', 'IDAREACONOCIM', 'IDVSPROYECTOCOL'])

# %% [markdown]
# ## 7. Verificación final

# %%
pc.resumen(df, 'proyectos_vinculacion_disponible (procesado)')
df.head()
# Out:
# --- Resumen proyectos_vinculacion_disponible (procesado) ---
# Dimensiones: 2659 filas x 10 columnas
# Filas duplicadas: 0
# Columnas con nulos (%):
# IDAREACONOCIM    100.0
# FECHAINICIO        2.1
# FECHAFIN           2.0
# dtype: float64
#    IDPERSONA  IDPROYECTOINVESTIGACION  \
# 0       1252                      225
# 1       2283                      217
# 2       2283                      213
# 3       2701                      222
# 4       2701                      226
#
#                                       NOMBREPROYECTO  \
# 0  Diseño e implementación de un sistema de infor...
# 1  Fortalecimiento a comunidades del Golfo de Gua...
# 2  Implementación de un Plan Piloto de Comerciali...
# 3    Centro de Atención Gratuita. (Gastos Generales)
# 4  Fortalecimiento de microempresas a través del ...
#
#                                       NOMBREPROGRAMA  IDAREACONOCIM  \
# 0                            Excelencia Hospitalaria           <NA>
# 1  Fortalecimiento de las capacidades de manejo y...           <NA>
# 2  Fortalecimiento de las capacidades de manejo y...           <NA>
# 3                        Centro de Atención Gratuita           <NA>
# 4                        Centro de Atención Gratuita           <NA>
#
#   FECHAINICIO FECHAFIN                                        REFARCHIVO1  \
# 0         NaT      NaT  https://practicas.espol.edu.ec/Proyecto/Proyec...
# 1         NaT      NaT  https://practicas.espol.edu.ec/Proyecto/Proyec...
# 2         NaT      NaT  https://practicas.espol.edu.ec/Proyecto/Proyec...
# 3         NaT      NaT  https://practicas.espol.edu.ec/Proyecto/Proyec...
# 4         NaT      NaT  https://practicas.espol.edu.ec/Proyecto/Proyec...
#
#             ROLPROYECTO  IDVSPROYECTOCOL
# 0  DIRECTOR DE PROYECTO                0
# 1  DIRECTOR DE PROGRAMA                0
# 2  DIRECTOR DE PROYECTO                0
# 3  DIRECTOR DE PROGRAMA                0
# 4  DIRECTOR DE PROGRAMA                0

# %% [markdown]
# ## 8. Guardado en data/processed

# %%
pc.guardar_procesado(df, 'proyectos_vinculacion_disponible.csv')
# Out:
# Guardado: D:\Proyecto_Tesis\data\processed\proyectos_vinculacion_disponible.csv (2659 filas x 10 columnas)
# WindowsPath('D:/Proyecto_Tesis/data/processed/proyectos_vinculacion_disponible.csv')
